# %% [markdown]
# <a href="https://colab.research.google.com/github/ameenamk/python/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
print(3)
# Out:
# 3

# %%
print("Ameena","Mk")
# Out:
# Ameena Mk

# %%
print(3,4,"hello",5)
# Out:
# 3 4 hello 5

# %%
print("Enter your name")
x=input()
print("Hello " +x)
# Out:
# Enter your name
# Ameena
# Hello Ameena

# %%
type(x)
# Out:
# str

# %%
x=input("Enter your name")
print("Hi "+x)
# Out:
# Enter your nameAmeena
# Hi Ameena

# %%
a=5.4
b="My value is"
print(b,a)
# Out:
# My value is 5.4

# %%
type(a)
# Out:
# float

# %%
x=str(3)
print(x,type(x))
y=int(3)
print(y,type(y))
z=float(3)
print(z,type(z))
# Out:
# 3 <class 'str'>
# 3 <class 'int'>
# 3.0 <class 'float'>

# %%
x=5
y=2
z=x+y
z1=x-y
z2=x*y
z3=x/y
z4=x ** y
print(z,z1,z2,"%.4f" %z3,z4)
# Out:
# 7 3 10 2.5000 25

# %%
w= x % y
print(w)
# Out:
# 1

# %%
print(22//7)
# Out:
# 3

# %%
#Compute x^2 + y^2 and print its value
x=int(input("Enter frst number"))
y=int(input("Enter scnd no"))
z=x**2 + y **2
print(z)
# Out:
# Enter frst number2
# Enter scnd no4
# 20

# %%
#Read 2 nos and find sum
print(x+y)
# Out:
# 6

# %%
a=10
b=5
if a > b:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
a=10
b=50
if a > b:
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# b is greater than a
